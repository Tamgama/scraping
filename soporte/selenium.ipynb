# %%
# %pip install lxml
# Out:
# ...
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/fc/82/ace5a5676051e60355bd8fb945df7b1ba4f4fb8447f2010fb816bfd57724/lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 487.6 kB/s eta 0:00:08
#    - -------------------------------------- 0.2/3.8 MB 1.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.2/3.8 MB 1.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.3/3.8 MB 1.2 MB/s eta 0:00:03
#    --- ------------------------------------ 0.3/3.8 MB 1.1 MB/s eta 0:00:04
#    --- ------------------------------------ 0.3/3.8 MB 1.1 MB/s eta 0:00:04
#    --- ------------------------------------ 0.3/3.8 MB 824.9 kB/s eta 0:00:05
#    --- ------------------------------------ 0.3/3.8 MB 838.1 kB/s eta 0:00:05
# ...

# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.
import numpy

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.common.by import By  
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
import random
import time 
from time import sleep
 # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.
from tqdm import tqdm
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import re

import openpyxl

# %%
proxies = [
    "http://62.33.53.248:3128",
    "http://67.43.227.228:28679",
    "http://91.219.171.48:8952",
    "http://67.43.228.250:19253",
    "http://89.35.237.187:80",
    "http://185.105.89.249:4444",
    "http://85.209.153.173:4153",
    "http://85.209.153.173:80",
    "http://103.73.66.36:8085",
    "http://39.109.113.97:3128",
    "http://72.10.164.178:11365",
    "http://72.10.164.178:4503",
    "http://67.43.228.252:18691",
    "http://93.157.196.58:8080",
    "http://72.10.164.178:13595",
    "http://8.212.107.200:80",
    "http://167.102.133.106:80",
    "http://67.43.236.20:8263",
    "http://81.17.101.68:3128",
    "http://154.203.132.55:8080",
    "http://67.43.228.254:14645",
    "http://67.43.228.253:21173",
    "http://85.209.153.174:999",
    "http://72.10.160.170:11939",
    "http://72.10.160.90:30203",
    "http://58.9.2.49:5002",
    "http://219.65.42.165:80",
    "http://85.209.153.174:80",
    "http://200.24.153.151:999",
    "http://122.185.198.242:7999",
    "http://72.10.160.174:24881",
    "http://85.10.199.41:3128",
    "http://8.219.97.248:80",
    "http://213.91.232.94:8080",
    "http://152.26.229.42:9443",
    "http://65.109.194.23:80",
    "http://72.10.164.178:9485",
    "http://67.43.228.251:5387",
    "http://103.37.111.253:18081",
    "http://154.203.132.55:8090",
    "http://185.105.90.88:4444",
    "http://67.43.236.20:24559",
    "http://177.70.72.103:20183",
    "http://220.226.202.147:80",
    "http://70.186.128.126:8080",
    "http://161.34.35.226:3128",
    "http://118.70.184.10:31300",
    "http://123.25.15.209:9812",
    "http://72.10.164.178:19033",
    "http://67.43.236.22:13239",
    "http://191.102.248.9:8084",
    "http://67.43.236.21:15617",
    "http://89.35.237.187:5678",
    "http://103.138.185.1:83",
    "http://85.209.153.174:8080",
    "http://23.166.88.209:3128",
    "http://67.43.236.20:3013",
    "http://67.43.228.253:25295",
    "http://85.209.153.174:8888",
    "http://195.114.209.50:80",
    "http://125.20.29.73:8080",
    "http://157.100.69.36:999",
    "http://84.214.150.146:8080",
    "http://187.79.146.98:8080",
    "http://206.201.3.83:8095",
    "http://103.178.194.123:1111",
    "http://161.34.40.115:3128",
    "http://103.27.118.138:8080",
    "http://103.153.246.129:3125",
    "http://103.158.27.94:8090",
    "http://67.43.236.21:4171",
]

def get_proxy_driver(proxy):
    chrome_options = Options()
    chrome_options.add_argument(f'--proxy-server={proxy}')
    driver = webdriver.Chrome(options=chrome_options)
    return driver

# Rotar proxies después de un número específico de iteraciones
iterations_per_proxy = 5
iteration_count = 0

# Inicializar el driver con el primer proxy
current_proxy = random.choice(proxies)
driver = get_proxy_driver(current_proxy)

# %%
listado = {
    "ref": [],
    "nombre":[],
    "anunciante": [],
    "tlf": [],
    "precio": [],
    "direccion": [],
    "barrio": [],
    "ciudad": [],
    "actualizacion": [],
}

# %%
try:
    driver = webdriver.Chrome()
    sleep(2)
    driver.get("https://www.idealista.com/")
    sleep(3)
    #Quitamos lo de las cookies
    driver.find_element('css selector','#didomi-notice-disagree-button').click()
    sleep(3)
    busqueda = driver.find_element('id', "#campoBus").send_keys("Murcia, Murcia", Keys.ENTER)
    sleep(2)
    viviendas = driver.find_element("id", "#showAllLink").click()
    sleep(5)


    listing = driver.find_elements("id", "#main-content")
    # contenedor con los elementos en forma de lista

    for item in listing:
        iteration_count += 1

        if iteration_count % iterations_per_proxy == 0:
                driver.quit()
                current_proxy = random.choice(proxies)
                driver = get_proxy_driver(current_proxy)
                driver.get("https://www.idealista.com/")
                time.sleep(3)
                driver.find_element("css selector", '#didomi-notice-disagree-button').click() 
                time.sleep(3)
                busqueda = driver.find_element("css selector", "#campoBus")
                busqueda.send_keys("Murcia, Murcia", Keys.ENTER)
                time.sleep(2)
                driver.find_element("css selector", "showAllLink").click()
                time.sleep(5)

        listado["nombre"].append(driver.find_element("css selector", "#main-content > section.items-container.items-list > article:nth-child(2) > div > a").text)
        sleep(2)
        listado["precio"].append(driver.find_element("css selector","#main-content > section.items-container.items-list > article:nth-child(2) > div > div.price-row > span.item-price.h2-simulated").text)
        sleep(2)

        entrar = driver.find_element("css selector", "#main-content > section.items-container.items-list > article:nth-child(2)")
        sleep(1)
        entrar.click()
        sleep(3)

        try:
            
            llamar = listing.find_element("ccs selector", "#contact-phones-container > a.see-phones-btn.icon-phone.hidden-contact-phones_link > span.hidden-contact-phones_text")
            llamar.click()
            time.sleep(2)  # Esperar a que el número de teléfono se muestre

            tlf = listing.find_element("css selector", "#contact-phones-container > a.icon-phone.hidden-contact-phones_formatted-phone._mobilePhone > span.hidden-contact-phones_text").text.strip()
        except:
            tlf = "N/A"

        listado["tlf"].append(tlf)
        sleep(3)
        listado["ref"].append(driver.find_element("css selector", ".txt-ref").text)
        listado["direccion"].append(driver.find_element("css selector", "#headerMap > ul > li:nth-child(1)").text)
        sleep(2)
        listado["barrio"].append(driver.find_element("css selector", "#headerMap > ul > li:nth-child(2)").text)
        sleep(5)
        listado["ciudad"].append(driver.find_element("css selector", "#headerMap > ul > li:nth-child(4)").text)
        sleep(1)
        listado["anunciante"].append(driver.find_element("css selector", "#module-contact-container > section > div > div.ide-box-contact.module-contact-gray.contact-data-container > div.professional-name > div").text)
        sleep(3)
        listado["actualizacion"].append(driver.find_element("css selector", "#stats > p").text)

        driver.back()
        sleep(2)

finally:
     driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[8], line 7
#       5 sleep(3)
#       6 #Quitamos lo de las cookies
# ----> 7 driver.find_element('css selector','#didomi-notice-disagree-button').click()
#       8 sleep(3)
#       9 busqueda = driver.find_element('id', "#campoBus").send_keys("Murcia, Murcia", Keys.ENTER)
#
# File ~/workspace/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/workspace/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
# ...

# %%
df_propietarios = pd.DataFrame(listado)
df_propietarios
