# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# %%
alquiler = pd.read_csv("alquileres-corregido.csv")
alquiler.head(1)
# Out:
#    id_inmueble      tipo  \
# 0    106299237  Alquiler
#
#                                                                      titulo  \
# 0  Alquiler de Piso en avenida de la libertad, 30012 barrio del progreso, 2
#
#                                                       calle   barrio  zona  \
# 0  \nAvenida de la libertad, 30012 barrio del progreso, 2\n  Avenida  Este
#
#        ciudad  \
# 0  \nMurcia\n
#
#                                                                           localizacion  \
# 0  \nAvenida de la libertad, 30012 barrio del progreso, 2\n, Avenida, Este, \nMurcia\n
#
#      precio precio_metro  \
# 0  700€/mes    7,78 €/m²
#
#                                                                                                                                                                                                                                                                                               caracteristicas  \
# ...

# %%
alqui = alqui.drop(['Metros_construidos', 'Metros_utilesBaños', 'Nombre_Anunciante', 'Última_Actualización'], axis=1)

# %%
alqui.head(1)
# Out:
#    ID_Inmueble      Tipo                              Título  \
# 0    106261442  Alquiler  Alquiler de Ático en ronda Sur, 20
#
#                Calle              Barrio              Distrito  \
# 0  \nRonda Sur, 20\n  \nUrb. ronda sur\n  \nBarrio Ronda Sur\n
#
#              Ciudad        Área    Precio Fianza Precio_por_metro  \
# 0  \nDistrito Sur\n  \nMurcia\n  900€/mes    NaN        6,43 €/m²
#
#                                                                                                                                                                                                                                                                                                  Características  \
# ...

# %%
ventas = ventas.rename(columns={"ID Inmueble": "ID_Inmueble", "Precio/m²": "Precio_por_metro", })
ventas.head(1)
# Out:
#    ID_Inmueble   Tipo                                               Título  \
# 0  106260336.0  venta  Chalet adosado en venta en avenida Cresta del Gallo
#
#                           Calle                          Barrio  \
# 0  \nAvenida Cresta del Gallo\n  \nBarrio San José de la Vega\n
#
#                      Distrito      Ciudad                        Área  \
# 0  \nDistrito Pedanías Este\n  \nMurcia\n  \nÁrea de Murcia, Murcia\n
#
#      Precio  Comunidad Precio_por_metro  \
# 0  139.000€        NaN         650 €/m²
#
#                                                                                                                                                                                                                                                                            Características  \
# ...

# %%
ventas.columns.tolist()
# Out:
# ['ID_Inmueble',
#  'Tipo',
#  'Título',
#  'Calle',
#  'Barrio',
#  'Distrito',
#  'Ciudad',
#  'Área',
#  'Precio',
#  'Comunidad',
#  'Precio_por_metro',
#  'Características',
#  'Habitaciones',
#  'Baños',
#  'Referencia',
#  'Anunciante',
#  'Nombre_Anunciante',
#  'Última Actualización',
#  'Teléfono',
#  'URL',
#  'fecha',
#  'direccion_completa']

# %%
order =['ID_Inmueble',
 'Tipo',
 'Título',
 'Calle',
 'Barrio',
 'Distrito',
 'Ciudad',
 'Área',
 'Precio',
 'Comunidad',
 'Precio_por_metro',
 'Características',
 'Habitaciones',
 'Baños',
 'Referencia',
 'Anunciante',
 'Nombre Anunciante',
 'Teléfono',
 'Última Actualización',
 'URL']

ventas = ventas.reindex(columns=order)
ventas
# Out:
#       ID_Inmueble   Tipo  \
# 0     106260336.0  venta
# 1     106262161.0  venta
# 2     106266940.0  venta
# 3     106266654.0  venta
# 4     106260682.0  venta
# ...           ...    ...
# 2538  105433581.0  venta
# 2539  105395068.0  venta
# 2540  105227920.0  venta
# 2541  104950816.0  venta
# 2542  104395506.0  venta
#
#                                                          Título  \
# 0           Chalet adosado en venta en avenida Cresta del Gallo
# 1                Chalet adosado en venta en calle Cervantes, 23
# 2     Casa o chalet independiente en venta en calle Ninguna, 22
# 3                       Dúplex en venta en calle Cementerio s/n
# 4              Estudio en venta en calle Donantes de Sangre s/n
# ...                                                         ...
# 2538                     Piso en venta en La Purísima-Barriomar
# 2539                    Casa de pueblo en venta en Javalí Nuevo
# 2540          Casa o chalet independiente en venta en El Palmar
# ...

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2543 entries, 0 to 2542
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Inmueble           2543 non-null   float64
#  1   Tipo                  2543 non-null   object
#  2   Título                2543 non-null   object
#  3   Calle                 2543 non-null   object
#  4   Barrio                2542 non-null   object
#  5   Distrito              2542 non-null   object
#  6   Ciudad                2540 non-null   object
#  7   Área                  1572 non-null   object
#  8   Precio                2540 non-null   object
#  9   Comunidad             0 non-null      float64
#  10  Precio_por_metro      2540 non-null   object
#  11  Características       2540 non-null   object
#  12  Habitaciones          2540 non-null   object
#  13  Baños                 2540 non-null   object
#  14  Referencia            2540 non-null   object
# ...

# %%
order1 = ['ID_Inmueble',
 'Tipo',
 'Título',
 'Calle',
 'Barrio',
 'Distrito',
 'Ciudad',
 'Área',
 'Precio',
 'Fianza',
 'Precio_por_metro',
 'Características',
 'Habitaciones',
 'Baños',
 'Referencia',
 'Anunciante',
 'Nombre Anunciante',
 'Última Actualización',
 'Teléfono',
 'URL']

alqui = alqui.reindex(columns=order1)
alqui
# Out:
#       ID_Inmueble      Tipo                                          Título  \
# 0       106261442  Alquiler              Alquiler de Ático en ronda Sur, 20
# 1        98516994  Alquiler  Alquiler de Piso en plaza Concepción Alemán, 2
# 2       106268350  Alquiler           Alquiler de Piso en calle Juan Bonafé
# 3       106262370  Alquiler    Alquiler de Piso en calle Enrique Alcaraz, 1
# 4       106263718  Alquiler               Alquiler de Dúplex en Torreagüera
# ...           ...       ...                                             ...
# 1749    105412103  Alquiler   Alquiler de Piso en calle Sierra de Gredos, 3
# 1750     85501765  Alquiler                     Alquiler de Piso en La Fama
# 1751    105509525  Alquiler                  Alquiler de Piso en San Miguel
# 1752    102293909  Alquiler                 Alquiler de Piso en c merced, 8
# 1753     25738059  Alquiler             Alquiler de Estudio en de Garay, 13
#
# ...

# %%
alqui.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754 entries, 0 to 1753
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Inmueble           1754 non-null   int64
#  1   Tipo                  1754 non-null   object
#  2   Título                1754 non-null   object
#  3   Calle                 1754 non-null   object
#  4   Barrio                1754 non-null   object
#  5   Distrito              1754 non-null   object
#  6   Ciudad                1754 non-null   object
#  7   Área                  1386 non-null   object
#  8   Precio                1754 non-null   object
#  9   Fianza                738 non-null    object
#  10  Precio_por_metro      1754 non-null   object
#  11  Características       1754 non-null   object
#  12  Habitaciones          1754 non-null   object
#  13  Baños                 1754 non-null   object
#  14  Referencia            1754 non-null   object
# ...

# %%
alqui.columns.tolist()
# Out:
# ['ID_Inmueble',
#  'Tipo',
#  'Título',
#  'Calle',
#  'Barrio',
#  'Distrito',
#  'Ciudad',
#  'Área',
#  'Precio',
#  'Fianza',
#  'Precio_por_metro',
#  'Características',
#  'Habitaciones',
#  'Baños',
#  'Referencia',
#  'Anunciante',
#  'Nombre Anunciante',
#  'Última Actualización',
#  'Teléfono',
#  'URL']

# %%
df = pd.concat([alqui, ventas], axis=0, ignore_index=True)
df
# Out:
#       ID_Inmueble      Tipo  \
# 0     106261442.0  Alquiler
# 1      98516994.0  Alquiler
# 2     106268350.0  Alquiler
# 3     106262370.0  Alquiler
# 4     106263718.0  Alquiler
# ...           ...       ...
# 4292  105433581.0     venta
# 4293  105395068.0     venta
# 4294  105227920.0     venta
# 4295  104950816.0     venta
# 4296  104395506.0     venta
#
#                                                  Título  \
# 0                    Alquiler de Ático en ronda Sur, 20
# 1        Alquiler de Piso en plaza Concepción Alemán, 2
# 2                 Alquiler de Piso en calle Juan Bonafé
# 3          Alquiler de Piso en calle Enrique Alcaraz, 1
# 4                     Alquiler de Dúplex en Torreagüera
# ...                                                 ...
# 4292             Piso en venta en La Purísima-Barriomar
# 4293            Casa de pueblo en venta en Javalí Nuevo
# 4294  Casa o chalet independiente en venta en El Palmar
# ...

# %%
df = df.drop(['Fianza', 'Comunidad'], axis=1)

df.columns = df.columns.str.lower().str.replace(' ', '_')

df.rename(columns={'id_inmueble':'id',
                          'título':'titulo',
                          'área':'area',
                          'características':'caracteristicas',
                          'teléfono': 'tlf',
                          'última_actualización': 'ultima_actualizacion'}, inplace=True)

df
# Out:
#                id      tipo  \
# 0     106261442.0  Alquiler
# 1      98516994.0  Alquiler
# 2     106268350.0  Alquiler
# 3     106262370.0  Alquiler
# 4     106263718.0  Alquiler
# ...           ...       ...
# 4292  105433581.0     venta
# 4293  105395068.0     venta
# 4294  105227920.0     venta
# 4295  104950816.0     venta
# 4296  104395506.0     venta
#
#                                                  titulo  \
# 0                    Alquiler de Ático en ronda Sur, 20
# 1        Alquiler de Piso en plaza Concepción Alemán, 2
# 2                 Alquiler de Piso en calle Juan Bonafé
# 3          Alquiler de Piso en calle Enrique Alcaraz, 1
# 4                     Alquiler de Dúplex en Torreagüera
# ...                                                 ...
# 4292             Piso en venta en La Purísima-Barriomar
# 4293            Casa de pueblo en venta en Javalí Nuevo
# 4294  Casa o chalet independiente en venta en El Palmar
# ...

# %%
cols = ['calle', 'barrio', 'distrito', 'ciudad']
for col in cols:
    df[col] = df[col].str.replace('\n', '', regex=False)

df['titulo'] = df['titulo'].str.replace('Alquiler de ', '', regex=False)
df['area'] = df['area'].str.replace('Área de ', '', regex=False)
df['barrio'] = df['barrio'].str.replace('Barrio ', '', regex=False)
df['distrito'] = df['distrito'].str.replace('Distrito ', '', regex=False)

# Convertir todos los valores a números, coercionando errores a NaN
df['tlf'] = pd.to_numeric(df['tlf'], errors='coerce')

# Rellenar NaN con 0 (u otro valor) y convertir a int
df['tlf'] = df['tlf'].fillna(0).astype(int)

# %%
columnas = [
    'superficie',
    'superficie_util',
    'habitaciones',
    'baños',
    'terraza',
    'garaje',
    'estado',
    'armarios',
    'trastero',
    'orientacion',
    'amueblado',
    'calefaccion',
    'planta',
    'ascensor',
    'construccion',
    'movilidad_reducida'
]

for col in columnas:
    df[col] = None


df
# Out:
#                id      tipo  \
# 0     106261442.0  Alquiler
# 1      98516994.0  Alquiler
# 2     106268350.0  Alquiler
# 3     106262370.0  Alquiler
# 4     106263718.0  Alquiler
# ...           ...       ...
# 4292  105433581.0     venta
# 4293  105395068.0     venta
# 4294  105227920.0     venta
# 4295  104950816.0     venta
# 4296  104395506.0     venta
#
#                                                  titulo  \
# 0                                Ático en ronda Sur, 20
# 1                    Piso en plaza Concepción Alemán, 2
# 2                             Piso en calle Juan Bonafé
# 3                      Piso en calle Enrique Alcaraz, 1
# 4                                 Dúplex en Torreagüera
# ...                                                 ...
# 4292             Piso en venta en La Purísima-Barriomar
# 4293            Casa de pueblo en venta en Javalí Nuevo
# 4294  Casa o chalet independiente en venta en El Palmar
# ...

# %%
def extraer_y_asignar_caracteristicas(caracteristicas):
    # Convertir la lista en un solo string para facilitar el análisis
    caracteristicas_str = ' '.join(caracteristicas)
    
    # Extraer y asignar cada característica usando expresiones regulares
    
    # Superficie construida
    match = re.search(r'(\d+ m² construidos)', caracteristicas_str, re.IGNORECASE)
    if match:
        df['superficie'] = match.group(0)
    else:
        df['superficie'] = None
    
    # Superficie útil
    match = re.search(r'(\d+ m² útiles)', caracteristicas_str, re.IGNORECASE)
    if match:
        df['superficie_util'] = match.group(0)
    else:
        df['superficie_util'] = None
    
    # Habitaciones
    match = re.search(r'(\d+ habitaciones)', caracteristicas_str, re.IGNORECASE)
    if match:
        df['habitaciones'] = match.group(0)
    else:
        df['habitaciones'] = None
    
    # Baños
    match = re.search(r'(\d+ baños)', caracteristicas_str, re.IGNORECASE)
    if match:
        df['baños'] = match.group(0)
    else:
        df['baños'] = None
    
    # Planta
    match = re.search(r'Planta (\d+)', caracteristicas_str, re.IGNORECASE)
    if match:
        df['planta'] = match.group(1)  # Solo el número de planta
    else:
        df['planta'] = None
    
    # Ascensor
    df['ascensor'] = 'Con ascensor' if re.search(r'Con ascensor', caracteristicas_str, re.IGNORECASE) else None
    
    # Terraza
    df['terraza'] = 'Terraza' if re.search(r'Terraza', caracteristicas_str, re.IGNORECASE) else None
    
    # Garaje
    df['garaje'] = 'Plaza de garaje incluida en el precio' if re.search(r'Plaza de garaje', caracteristicas_str, re.IGNORECASE) else None
    
    # Estado
    df['estado'] = 'Segunda mano/buen estado' if re.search(r'Segunda mano/buen estado', caracteristicas_str, re.IGNORECASE) else None
    
    # Armarios
    df['armarios'] = 'Armarios empotrados' if re.search(r'Armarios empotrados', caracteristicas_str, re.IGNORECASE) else None
    
    # Orientación
    match = re.search(r'Orientación ([^,]+, [^,]+)', caracteristicas_str, re.IGNORECASE)
    if match:
        df['orientacion'] = match.group(1)
    else:
        df['orientacion'] = None
    
    # Amueblado
    df['amueblado'] = 'Amueblado y cocina equipada' if re.search(r'Amueblado y cocina equipada', caracteristicas_str, re.IGNORECASE) else None
    
    # Calefacción
    df['calefaccion'] = 'Calefacción central' if re.search(r'Calefacción central', caracteristicas_str, re.IGNORECASE) else None
    
    # Trastero
    df['trastero'] = 'Trastero' if re.search(r'Trastero', caracteristicas_str, re.IGNORECASE) else None
    


df.apply(lambda row: extraer_y_asignar_caracteristicas(row['caracteristicas']), axis=1)


df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 75
#      70     # Trastero
#      71     df['trastero'] = 'Trastero' if re.search(r'Trastero', caracteristicas_str, re.IGNORECASE) else None
# ---> 75 df.apply(lambda row: extraer_y_asignar_caracteristicas(row['caracteristicas']), axis=1)
#      78 df
#
# File ~/workspace/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/workspace/.venv/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
# ...

# %%
patterns = {
    'superficie': re.compile(r'(\d+)\s*m² construidos', re.IGNORECASE),
    'superficie_util': re.compile(r'(\d+)\s*m² útiles', re.IGNORECASE),
    'habitaciones': re.compile(r'(\d+)\s*habitaciones?', re.IGNORECASE),
    'baños': re.compile(r'(\d+)\s*baños?', re.IGNORECASE),
    'terraza': re.compile(r'(Terraza|Balcón)', re.IGNORECASE),
    'garaje': re.compile(r'(Plaza de garaje)', re.IGNORECASE),
    'estado': re.compile(r'(Segunda mano\b.*buen estado)', re.IGNORECASE),
    'armarios': re.compile(r'(Armarios empotrados)', re.IGNORECASE),
    'trastero': re.compile(r'(Trastero)', re.IGNORECASE),
    'orientacion': re.compile(r'Orientación\s([\w\s,]+)', re.IGNORECASE),
    'amueblado': re.compile(r'(Amueblado y cocina equipada|Cocina sin equipar y casa sin amueblar)', re.IGNORECASE),
    'calefaccion': re.compile(r'Calefacción (central|individual|No disponible calefaccion)', re.IGNORECASE),
    'planta': re.compile(r'Planta\s(\d+)(?:ª|\s)?(exterior|interior)', re.IGNORECASE),
    'ascensor': re.compile(r'(Con ascensor|Sin ascensor)', re.IGNORECASE),
    'construccion': re.compile(r'Construido en (\d{4})', re.IGNORECASE),
    'movilidad_reducida': re.compile(r'(Solo acceso exterior adaptado para personas con movilidad reducida)', re.IGNORECASE)
}

def extract_data(row, patterns):
    # Inicializa el diccionario con valores nulos para todas las columnas
    data = {col: np.nan for col in patterns.keys()}
    data['exterior_interior'] = np.nan  # Añadir columna específica para exterior/interior
    if isinstance(row, str):
        row = [row]
    for item in row:
        for key, pattern in patterns.items():
            match = pattern.search(item)
            if match:
                if key == 'planta':
                    data['planta'] = match.group(1)
                    data['exterior_interior'] = match.group(2)
                elif key == 'ascensor':
                    data[key] = 'Sí' if 'Con' in match.group(0) else 'No'
                elif key == 'amueblado':
                    data[key] = 'Amueblado' if 'Amueblado' in match.group(0) else 'No amueblado'
                elif key == 'calefaccion':
                    calef = match.group(1)
                    data[key] = calef if calef != 'No disponible calefaccion' else 'No disponible'
                elif key == 'orientacion':
                    data[key] = match.group(1)
                else:
                    data[key] = match.group(1)
                continue
    return data

# Aplicar la función a la columna 'caracteristicas'
df_extracted = df['caracteristicas'].apply(lambda row: extract_data(row, patterns))

# Convertir la serie de diccionarios a un DataFrame
df_extracted = pd.DataFrame(list(df_extracted))
# Actualizar las columnas de df con los valores extraídos
for col in df_extracted.columns:
    df[col] = df_extracted[col]

df
# Out:
#              id      tipo                                             titulo  \
# 0     105791782  Alquiler                  Piso en avenida Juan Carlos I, 92
# 1     105544224  Alquiler                      Piso en luis fontes pagan, 11
# 2     105795869  Alquiler                           Ático en calle Mayor, 97
# 3      31330943  Alquiler                     Ático en La Purísima-Barriomar
# 4     105795813  Alquiler                           Piso en calle Hilanderas
# ...         ...       ...                                                ...
# 1743  105433581     venta             Piso en venta en La Purísima-Barriomar
# 1744  105395068     venta            Casa de pueblo en venta en Javalí Nuevo
# 1745  105227920     venta  Casa o chalet independiente en venta en El Palmar
# 1746  104950816     venta             Piso en venta en Santa María de Gracia
# 1747  104395506     venta        Casa o chalet en venta en San Benito-Patiño
#
# ...

# %%
df.to_csv('../src/data.csv')
