# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../alquileres.csv", index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, 105795869 to 101303045
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Tipo                     301 non-null    object
#  1   Título                   301 non-null    object
#  2   Calle                    301 non-null    object
#  3   Barrio                   301 non-null    object
#  4   Distrito                 301 non-null    object
#  5   Ciudad                   301 non-null    object
#  6   Área                     269 non-null    object
#  7   Precio                   301 non-null    object
#  8   Fianza                   208 non-null    object
#  9   Precio/m²                0 non-null      float64
#  10  Características          0 non-null      float64
#  11  Habitaciones             301 non-null    object
#  12  Baños                    301 non-null    object
#  13  Referencia               301 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Tipo                         0
# Título                       0
# Calle                        0
# Barrio                       0
# Distrito                     0
# Ciudad                       0
# Área                        32
# Precio                       0
# Fianza                      93
# Precio/m²                  301
# Características            301
# Habitaciones                 0
# Baños                        0
# Referencia                   0
# Anunciante                   5
# Nombre Anunciante            0
# Última Actualización         0
# Teléfono                     5
# URL                          0
# Características Básicas      0
# m construidos                0
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Tipo',
#  'Título',
#  'Calle',
#  'Barrio',
#  'Distrito',
#  'Ciudad',
#  'Área',
#  'Precio',
#  'Fianza',
#  'Precio/m²',
#  'Características',
#  'Habitaciones',
#  'Baños',
#  'Referencia',
#  'Anunciante',
#  'Nombre Anunciante',
#  'Última Actualización',
#  'Teléfono',
#  'URL',
#  'Características Básicas',
#  'm construidos']

# %%
# Eliminar saltos de línea en columnas

df.loc[df['Precio_por_metro'].astype(str).str.contains('\n')]

for elemto in df[df.loc[df['Precio_por_metro'].astype(str).str.contains('\n')]]:
    df[elemto] = df[elemto].str.replace('\n','')

# %%
df
# Out:
#                  Tipo                                          Título  \
# ID Inmueble
# 105795869    Alquiler            Alquiler de Ático en calle Mayor, 97
# 105544224    Alquiler       Alquiler de Piso en luis fontes pagan, 11
# 105795813    Alquiler            Alquiler de Piso en calle Hilanderas
# 31330943     Alquiler      Alquiler de Ático en La Purísima-Barriomar
# 103056344    Alquiler  Alquiler de Piso en calle san luis gongaza s/n
# ...               ...                                             ...
# 105409489    Alquiler              Alquiler de Piso en calle Matadero
# 515992       Alquiler             Alquiler de Estudio en calle Alfaro
# 105221763    Alquiler     Alquiler de Piso en calle Alejandro Seiquer
# 101193140    Alquiler         Alquiler de Dúplex en calle Acacias, 25
# 101303045    Alquiler             Alquiler de Piso en Angel Romero, 3
#
#                                         Calle  \
# ID Inmueble
# 105795869                 \nCalle Mayor, 97\n
# ...
