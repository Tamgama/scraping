# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("alquileres.csv", index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 896 entries, 105791782 to 25738059
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Tipo                  896 non-null    object
#  1   Título                896 non-null    object
#  2   Calle                 896 non-null    object
#  3   Barrio                896 non-null    object
#  4   Distrito              896 non-null    object
#  5   Ciudad                896 non-null    object
#  6   Área                  747 non-null    object
#  7   Precio                896 non-null    object
#  8   Fianza                612 non-null    object
#  9   Precio_por_metro      896 non-null    object
#  10  Características       896 non-null    object
#  11  Habitaciones          896 non-null    object
#  12  Metros_construidos    0 non-null      float64
#  13  Metros_utilesBaños    0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# Tipo                      0
# Título                    0
# Calle                     0
# Barrio                    0
# Distrito                  0
# Ciudad                    0
# Área                    149
# Precio                    0
# Fianza                  284
# Precio_por_metro          0
# Características           0
# Habitaciones              0
# Metros_construidos      896
# Metros_utilesBaños      896
# Referencia                0
# Anunciante               22
# Nombre_Anunciante       896
# Última_Actualización    896
# Teléfono                 68
# URL                       0
# Baños                     0
# Nombre Anunciante         0
# Última Actualización      0
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Tipo',
#  'Título',
#  'Calle',
#  'Barrio',
#  'Distrito',
#  'Ciudad',
#  'Área',
#  'Precio',
#  'Fianza',
#  'Precio_por_metro',
#  'Características',
#  'Habitaciones',
#  'Metros_construidos',
#  'Metros_utilesBaños',
#  'Referencia',
#  'Anunciante',
#  'Nombre_Anunciante',
#  'Última_Actualización',
#  'Teléfono',
#  'URL',
#  'Baños',
#  'Nombre Anunciante',
#  'Última Actualización']

# %%
# Eliminar saltos de línea en columnas

df.loc[df['Precio_por_metro'].astype(str).str.contains('\n')]

for elemto in df[df.loc[df['Precio_por_metro'].astype(str).str.contains('\n')]]:
    df[elemto] = df[elemto].replace('\n','')

# %%
df['título'] = df['título'].str.replace('Alquiler de ', '', regex=False)
df['área'] = df['área'].str.replace('Área de ', '', regex=False)
df['fianza'] = df['fianza'].str.replace('Fianza de ', '', regex=False)
df['barrio'] = df['barrio'].str.replace('Barrio ', '', regex=False)
df['distrito'] = df['distrito'].str.replace('Distrito ', '', regex=False)

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df
# Out:
#                  tipo                             título  \
# ID_Inmueble
# 105791782    Alquiler  Piso en avenida Juan Carlos I, 92
# 105544224    Alquiler      Piso en luis fontes pagan, 11
# 105795869    Alquiler           Ático en calle Mayor, 97
# 31330943     Alquiler     Ático en La Purísima-Barriomar
# 105795813    Alquiler           Piso en calle Hilanderas
# ...               ...                                ...
# 105412103    Alquiler  Piso en calle Sierra de Gredos, 3
# 85501765     Alquiler                    Piso en La Fama
# 105509525    Alquiler                 Piso en San Miguel
# 102293909    Alquiler                Piso en c merced, 8
# 25738059     Alquiler            Estudio en de Garay, 13
#
#                                     calle                  barrio  \
# ID_Inmueble
# 105791782       Avenida Juan Carlos I, 92      Zona Juan Carlos I
# 105544224           luis fontes pagan, 11              Vistabella
# ...
