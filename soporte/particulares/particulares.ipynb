# %%
pip install pydrive google-auth-oauthlib
# Out:
# Requirement already satisfied: pydrive in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (1.3.1)
# Requirement already satisfied: google-auth-oauthlib in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from pydrive) (2.149.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from pydrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from pydrive) (6.0.2)
# Requirement already satisfied: google-auth>=2.15.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-auth-oauthlib) (2.35.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (2.21.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-api-python-client>=1.2->pydrive) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from oauth2client>=4.0.0->pydrive) (0.6.1)
# Requirement already satisfied: six>=1.6.1 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from oauth2client>=4.0.0->pydrive) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (5.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (1.24.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.2->pydrive) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/workspace/.venv/lib/python3.12/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
df = pd.read_csv("../../web_2/data/inmuebles.csv")

particulares = df[df["anunciante"] == "Particular"]
particulares
# Out:
#                id      tipo  \
# 0     106246747.0     venta
# 1     106246873.0     venta
# 2      30786746.0  Alquiler
# 4     106246371.0  Alquiler
# 7     106245127.0     venta
# ...           ...       ...
# 4118  105443843.0     venta
# 4119  104742412.0     venta
# 4122  104766096.0     venta
# 4129  105066586.0     venta
# 4134  105433645.0     venta
#
#                                                  titulo  \
# 0                     Piso en venta en calle Morera, 52
# 1     Piso en venta en calle Fernando Sanchéz Agüera...
# 2                             Piso en San Benito-Patiño
# 4                       Ático en calle de la gloria, 57
# 7          Ático en venta en calle Saavedra Fajardo, 43
# ...                                                 ...
# 4118            Piso en venta en paseo de Florencia, 47
# 4119  Casa o chalet independiente en venta en calle ...
# 4122  Casa o chalet independiente en venta en calle ...
# 4129  Casa o chalet independiente en venta en vereda...
# 4134                 Piso en venta en calle Vinader, 11
#
#                                      calle                        barrio  \
# 0                         Calle Morera, 52             Santiago el Mayor
# 1        Calle Fernando Sanchéz Agüera, 20                     El Palmar
# 2                 Barrio San Benito-Patiño        Distrito Pedanías Este
# 4                   Calle de la gloria, 57                      San Juan
# 7               Calle Saavedra Fajardo, 43               Llano de Brujas
# ...                                    ...                           ...
# 4118                Paseo de Florencia, 47                     Ronda Sur
# 4119  Calle Alcalde Gaspar de La Peña, 100        San Andrés-San Antolín
# 4122                  Calle Mazarrón, 22 C           Jerónimo y Avileses
# 4129                 Vereda de la Cueva, 1                    Monteagudo
# 4134                     Calle Vinader, 11  Santa Catalina-San Bartolomé
#
#              distrito                  ciudad                area    precio  \
# 0                 Sur                  Murcia  \nMurcia, Murcia\n   75.000€
# 1      Pedanías Oeste                  Murcia  \nMurcia, Murcia\n  180.000€
# 2              Murcia  Área de Murcia, Murcia                 NaN  900€/mes
# 4              Centro                  Murcia  \nMurcia, Murcia\n  675€/mes
# 7       Pedanías Este                  Murcia  \nMurcia, Murcia\n  220.000€
# ...               ...                     ...                 ...       ...
# 4118              Sur                  Murcia  \nMurcia, Murcia\n       180
# 4119           Centro                  Murcia  \nMurcia, Murcia\n       480
# 4122  Campo de Murcia                  Murcia  \nMurcia, Murcia\n       179
# 4129   Pedanías Norte                  Murcia  \nMurcia, Murcia\n       280
# 4134           Centro                  Murcia  \nMurcia, Murcia\n       135
#
#      precio_por_metro  ...                    estado             armarios  \
# 0            938 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# 1          2.571 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# 2           9,00 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# 4          13,50 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# 7          1.068 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# ...               ...  ...                       ...                  ...
# 4118       1.698 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# 4119       1.200 €/m²  ...                       NaN  Armarios empotrados
# 4122       2.387 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# 4129         571 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
# 4134       3.140 €/m²  ...  Segunda mano/buen estado  Armarios empotrados
#
#       trastero              orientacion  amueblado calefaccion planta  \
# 0          NaN         sur, este, oeste        NaN         NaN    NaN
# 1     Trastero                      sur        NaN  individual    NaN
# 2          NaN                      sur  Amueblado     central    NaN
# 4          NaN                      NaN  Amueblado  individual    NaN
# 7     Trastero                sur, este        NaN  individual    NaN
# ...        ...                      ...        ...         ...    ...
# 4118  Trastero              norte, este        NaN         NaN    NaN
# 4119  Trastero  norte, sur, este, oeste        NaN         NaN    NaN
# 4122  Trastero                      sur        NaN  individual    NaN
# 4129       NaN  norte, sur, este, oeste        NaN         NaN    NaN
# 4134       NaN                      NaN        NaN         NaN    NaN
#
#       ascensor construccion                                 movilidad_reducida
# 0           No          NaN                                                NaN
# 1           Sí          NaN  Solo acceso exterior adaptado para personas co...
# 2           Sí          NaN                                                NaN
# 4           Sí          NaN                                                NaN
# 7           Sí       2006.0                                                NaN
# ...        ...          ...                                                ...
# 4118        Sí       2002.0  Solo acceso exterior adaptado para personas co...
# 4119       NaN          NaN                                                NaN
# 4122       NaN       2007.0  Solo acceso exterior adaptado para personas co...
# 4129       NaN          NaN                                                NaN
# 4134        Sí          NaN                                                NaN
#
# [740 rows x 34 columns]

# %%
# Autenticar la aplicación
gauth = GoogleAuth()
gauth.LocalWebserverAuth()  # Esto abrirá una ventana del navegador para autenticarse

gauth.LoadCredentialsFile("credentials.json")  # Cargar token de autenticación
if not gauth.credentials or gauth.access_token_expired:
    gauth.LocalWebserverAuth()  # Autenticarse si no hay token o está vencido
    gauth.SaveCredentialsFile("credentials.json")  # Guardar token para la próxima vez


drive = GoogleDrive(gauth)

# Subir el archivo Excel a Google Drive
file_drive = drive.CreateFile({'title': 'particulares.xlsx'})  # Cambia el título según desees
file_drive.SetContentFile('particulares.xlsx')  # Archivo que queremos subir
file_drive.Upload()
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=586740864741-fdpjo0t8scbj3011plhcr0ia072prkb3.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.
